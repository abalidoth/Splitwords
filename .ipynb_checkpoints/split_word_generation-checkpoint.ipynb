# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import json

# %%
clues = pd.read_csv("clues_clean.csv").drop("Unnamed: 0", axis=1)

# %%
clues.sample(10)
# Out:
#        index   answer                                   clue_1  \
# 2493    2493    ASPCA                            Adoption org.
# 15289  15289      LAM                                   Escape
# 20122  20122   OPENTO                             Entertaining
# 19309  19309     OATS                            Cereal grains
# 31413  31413   WAHOOS                             Cowboy cries
# 28914  28914  TENANTS                       Apartment dwellers
# 15881  15881  LETSOUT                                 Divulges
# 21721  21721  PLAYPEN                         Baby's enclosure
# 25286  25286     SEEM                                   Appear
# 14312  14312     ITAS  But I must also feel ___ a man: Macduff
#
#                           clue_2                    clue_3  \
# 2493                 Humane org.    Humane org. since 1866
# 15289           Escapee's flight                    Flight
# 20122       Interested in trying         Not dismissive of
# 19309                 Horse feed                 Mare fare
# 31413  Cries at a Wild West show             Elated cheers
# 28914      Dwellers in complexes              Flat people?
# 15881           Ends, as a class            Ends, as class
# 21721        Corral for a kiddie  Infant's recreation area
# 25286                     Appear                    Appear
# 14312        Take ___ a blessing       Take ___ a blessing
#
#                                   clue_4                  clue_5  \
# 2493     Org. that facilitates adoptions       Pet adoption org.
# 15289                 Head for the hills          Hurried flight
# 20122               Not entirely against          Not ruling out
# 19309                        Mare's meal          Mares eat them
# 31413                    Exuberant cries        Exuberant shouts
# 28914                  Lease signatories     Many urban dwellers
# 15881  Frees for a bit, catlover's style       Frees from prison
# 21721                         Kiddy coop  Place to put some toys
# 25286                       Appear to be          Come across as
# 14312              Take ___ a compliment   Take ___ a compliment
#
#                               clue_6                    clue_7  \
# 2493             Pet protection org.       Pet protection org.
# 15289              Make a run for it      On the ___ (fleeing)
# 20122            Not totally against                 Receptive
# 19309                  Overnight ___     Part of a stable diet
# 31413  Exuberant-sounding mackerels?     Large, swift mackerel
# 28914            Monthly rent payers  Rent strike participants
# 15881                        Paroles                   Paroles
# 21721            Toddler's enclosure       Toddlers' enclosure
# 25286                    Come off as               Come off as
# 14312          Take ___ a compliment     Take ___ a compliment
#
#                              clue_8  \
# 2493       Pet protector, for short
# 15289                 Take a powder
# 20122           Willing to consider
# 19309                    Quaker ___
# 31413       Shouts heard at a rodeo
# 28914       Security deposit payers
# 15881                      Releases
# 21721                      Tot spot
# 25286  Give the impression of being
# 14312        Take ___ a compliment!
#
#                                            clue_9  \
# 2493                             Pet welfare grp.
# 15289              Taking it on the ___ (fleeing)
# 20122                              Willing to try
# 19309                              Stable staples
# 31413  University of Virginia players, familiarly
# 28914                The Ricardos, to the Mertzes
# 15881                                    Releases
# 21721                             Tot's enclosure
# 25286                      Have the appearance of
# 14312                              Take ____ read
#
#                                            clue_10
# 2493                       We Are Their Voice org.
# 15289                                       Thrash
# 20122                               ___ the public
# 19309  Texas is the largest U.S. producer of these
# 31413                         Warm-water mackerels
# 28914           They're in your apartment building
# 15881                             Spills the beans
# 21721                                   Tot's turf
# 25286                                  Look (like)
# 14312                      Take _____ a compliment

# %%
clues["length"]=[len(x) for x in clues.answer]

# %%
clues_by_length = {l:t for l,t in clues.groupby("length")}

# %%
clues_by_length[3]
# Out:
#        index answer                  clue_1                    clue_2  \
# 0          0    AAA             Battery buy              Battery type
# 4          4    AAH          Contented sigh  Exclamation of amazement
# 13        13    AAR           Alpine stream             Berne's river
# 19        19    AAS       Certain batteries   Remote batteries, often
# 20        20    AAU     Amateur sports org.            Athletes' grp.
# ...      ...    ...                     ...                       ...
# 32443  32443    ZIT                Bad spot               Bit of acne
# 32446  32446    ZOA     Animal group suffix      Animals, in taxonomy
# 32448  32448    ZOE        Actress Caldwell    Avatar actress Saldana
# 32456  32456    ZOO  Business with habitats             Chaotic place
# 32468  32468    ZSA      Eva's half-sister?        Eva's half-sister?
#
#                                      clue_3  \
# 0                              Battery type
# 4                                Now I see!
# 13                             Rhine feeder
# 19                          Small batteries
# 20     Org. that bestows the Sullivan Award
# ...                                     ...
# 32443                      Clearasil target
# 32446      Combining form meaning "animals"
# 32448        Four-time Tony winner Caldwell
# 32456                         Chaotic scene
# 32468                     Half a Gabor name
#
#                                             clue_4  \
# 0                                         Car club
# 4                                      Ooh and ___
# 13                  Rhine tributary of Switzerland
# 19                                 Small batteries
# 20     Org. that gives the James E. Sullivan Award
# ...                                            ...
# 32443                                 Oxy 5 target
# 32446                           Ending with proto-
# 32448                High Fidelity actress Kravitz
# 32456                                Chaotic scene
# 32468                          Half-sister of Eva?
#
#                                                   clue_5  \
# 0                                      Certain batteries
# 4                                          Ooh's partner
# 13                                           Swiss river
# 19                                       Small batteries
# 20     Org. with the Sullivan Award for character, le...
# ...                                                  ...
# 32443                                             Pimple
# 32446                                  Organisms: Suffix
# 32448                      Orange "Sesame Street" Muppet
# 32456                                  Chaotic situation
# 32468                             Hungarian half sister?
#
#                                                   clue_6  \
# 0                                    Driver's aid: Abbr.
# 4                                         Open-wide word
# 13                                           Swiss river
# 19                                       Small batteries
# 20     Org. with the Sullivan Award for character, le...
# ...                                                  ...
# 32443              Problem before a big date, informally
# 32446                           Suffix meaning "animals"
# 32448                                   Playwright Akins
# 32456                      Dr. Seuss' "If I Ran the ___"
# 32468                              When doubled, a Gabor
#
#                                              clue_7  \
# 0                                    Little battery
# 4      Something you might say at a doctor's office
# 13                                      Swiss river
# 19                                  Small batteries
# 20        Org. with the annual Junior Olympic Games
# ...                                             ...
# 32443                        Skin blemish, slangily
# 32446                      Suffix meaning "animals"
# 32448           Saldana of "Avengers: Infinity War"
# 32456                                      Madhouse
# 32468      When repeated, a first name in Hollywood
#
#                                         clue_8  \
# 0                     Roadside assistance org.
# 4                             Sound of delight
# 13                  Swiss river into the Rhine
# 19                              Some batteries
# 20                Sports For All, Forever org.
# ...                                        ...
# 32443                    Teen's facial blemish
# 32446                       Suffix with proto-
# 32448     Saldana of "Guardians of the Galaxy"
# 32456                                Menagerie
# 32468  When repeated, one of the Gabor sisters
#
#                                  clue_9                           clue_10  \
# 0                        Rte. suggester                Small battery size
# 4                 That feels g-o-o-o-d!             Word said to a doctor
# 13             Swiss river to the Rhine           Switzerland's ___ Gorge
# 19            Some flashlight batteries                      ___ in apple
# 20                          Sports org.  Sports org. for nonprofessionals
# ...                                 ...                               ...
# 32443               Temple imperfection            Tough spot for a teen?
# 32446                Suffix with proto-                   Taxonomy suffix
# 32448              Tony winner Caldwell              Tony winner Caldwell
# 32456        Where the wild things are?  Workplace for some veterinarians
# 32468  When repeated, one of the Gabors  When repeated, one of the Gabors
#
#        length
# 0           3
# 4           3
# 13          3
# 19          3
# 20          3
# ...       ...
# 32443       3
# 32446       3
# 32448       3
# 32456       3
# 32468       3
#
# [2264 rows x 13 columns]

# %%
decompose_word("ZYDECO")
# Out:
# [['Z', 'Y', 'D', 'E', 'C', 'O'],
#  ['Z', 'Y', 'D', 'E', 'CO'],
#  ['Z', 'Y', 'D', 'CE', 'O'],
#  ['Z', 'Y', 'DE', 'C', 'O'],
#  ['Z', 'Y', 'DE', 'CO'],
#  ['Z', 'DY', 'E', 'C', 'O'],
#  ['Z', 'DY', 'E', 'CO'],
#  ['Z', 'DY', 'CE', 'O'],
#  ['YZ', 'D', 'E', 'C', 'O'],
#  ['YZ', 'D', 'E', 'CO'],
#  ['YZ', 'D', 'CE', 'O'],
#  ['YZ', 'DE', 'C', 'O'],
#  ['YZ', 'DE', 'CO']]

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %%
character_set = list(alphabet)+[alphabet[i]+alphabet[j] for i in range(26) for j in range(i,26)]

# %%
len(character_set)
# Out:
# 377

# %%
character_set[-1]
# Out:
# 'ZZ'

# %%
char_table = {ch:n for n,ch in enumerate(character_set)}
idx_table = {n:ch for n,ch in enumerate(character_set)}

# %%
def decompose_word(w):
    if len(w) == 0:
        return []
    elif len(w) == 1:
        return [[w]]
    elif len(w) == 2:
        return [[w[0],w[1]],["".join(sorted(w))]]
    else:
        out = []
        first = w[0]
        first_suffix = decompose_word(w[1:])
        for i in first_suffix:
            out.append([first]+i)
        pair = "".join(sorted(w[:2]))
        second_suffix = decompose_word(w[2:])
        for i in second_suffix:
            out.append([pair]+i)
        return out

# %%
def decomp_to_idx(l):
    return tuple(char_table[i] for i in l)

# %%
[decomp_to_idx(x) for x in decompose_word("ZYDECO")]
# Out:
# [(25, 24, 3, 4, 2, 14),
#  (25, 24, 3, 4, 89),
#  (25, 24, 3, 79, 14),
#  (25, 24, 102, 2, 14),
#  (25, 24, 102, 89),
#  (25, 122, 4, 2, 14),
#  (25, 122, 4, 89),
#  (25, 122, 79, 14),
#  (375, 3, 4, 2, 14),
#  (375, 3, 4, 89),
#  (375, 3, 79, 14),
#  (375, 102, 2, 14),
#  (375, 102, 89)]

# %%
tags_to_word_index =[]
tags_by_length = defaultdict(list)
for i, w in zip(clues["index"], clues["answer"]):
    d = decompose_word(w)
    for t in d:
        tags = decomp_to_idx(t)
        tags_to_word_index.append((i,tags))
        tags_by_length[len(tags)].append(tags)

# %%
len(tags_by_length[5])
# Out:
# 116792

# %%
len(tags_by_length)
# Out:
# 14

# %%
with open("tags_by_length.json", "w") as f:
    json.dump(tags_by_length,f, indent = 3)

# %%
with open("tags_to_word_index.json","w") as f:
    json.dump(tags_to_word_index, f, indent=3)
