# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import json

# %%
clues = pd.read_csv("clues_clean.csv").drop("Unnamed: 0", axis=1).reset_index()

# %%
clues.sample(10)
# Out:
#        index   answer                      clue_1                    clue_2  \
# 22573  22573    RACER             Dash competitor                   Go-cart
# 21712  21712  PLATTER               *Serving dish                  45, e.g.
# 13941  13941     INSO  I love you _____ many ways        Not ___ many words
# 15413  15413    LASER               Cutting light  Cutting-edge technology?
# 15867  15867   LETOFF                      Acquit                    Acquit
# 847      847     AIMS           Aligns crosshairs                    Dreams
# 19584  19584     OHOK                  Ah, got it                Ah, gotcha
# 18845  18845      NIX                  Invalidate                  Overrule
# 24096  24096    RONEE  1975 Oscar nominee Blakley           Actress Blakley
# 31711  31711    WHERE              I don't see it        Invitation heading
#
#                        clue_3                          clue_4  \
# 22573            Jockey, e.g.              Marathon contender
# 21712          Diner offering  It may be uncovered before use
# 13941      Not ___ many words         Preceder of many words?
# 15413        Eye surgery tool          High-tech surgery tool
# 15867               Acquitted        Allowed to leave the bus
# 847                      Ends                           Goals
# 19584           Ah, now I see              Duh! Now I get it!
# 18845                Prohibit               Put the kibosh on
# 24096         Actress Blakley                 Actress Blakley
# 31711  Invitation information             One of the Five W's
#
#                        clue_5                          clue_6  \
# 22573           NASCAR driver             NASCAR driver  e.g.
# 21712                      LP                 Old-time record
# 13941    Start of many words?     Two words before many words
# 15413        Hologram creator                 Kind of printer
# 15867  Excuse from punishment          Excuse from punishment
# 847                     Goals                      Objectives
# 19584            Now I get it            That makes sense now
# 18845              Shoot down                      Shoot down
# 24096         Actress Blakley  Actress Blakley of "Nashville"
# 31711     One of the Five W's        Question in a shell game
#
#                              clue_7                             clue_8  \
# 22573  One making a pit stop, maybe              One who sits in laps?
# 21712   Part of a caterer's display                           Pupu ___
# 13941      Words before many words?                     ___ many words
# 15413                   Sci-fi beam                   Star Wars weapon
# 15867    Excuse from responsibility                              Freed
# 847      Prepares to hit a cue ball         Prepares to shoot a basket
# 19584                      Um, sure                   Well, I guess so
# 18845                    Shoot down                Turn thumbs-down on
# 24096      Blakely  of    Nashville  Blakley of "Lightning Over Water"
# 31711             Seeker's question           Word in a geography quiz
#
#                                     clue_9  \
# 22573                       Toy on a track
# 21712  Something that turns on a turntable
# 13941                       ___ many words
# 15413                        Surgical beam
# 15867                      Give a reprieve
# 847                      Prepares to throw
# 19584                      Well, all right
# 18845                                 Veto
# 24096               Blakley of "Nashville"
# 31711                            ___ am I?
#
#                                      clue_10  clue_pct
# 22573                       Track competitor  0.906114
# 21712                   Special dinner order  0.283351
# 13941                         ___ many words  0.511913
# 15413                          Surgical beam  0.963247
# 15867                                Release  0.065925
# 847                        Uses one's sight?  0.774910
# 19584                   Well, all right then  0.243502
# 18845                                   Veto  0.542403
# 24096                 Blakley of "Nashville"  0.193039
# 31711  _____ Did Our Love Go (Supremes tune)  0.767117

# %%
clues["length"]=[len(x) for x in clues.answer]

# %%
clues_by_length = {l:t for l,t in clues.groupby("length")}

# %%
clues_by_length[3]
# Out:
#        index answer                      clue_1  \
# 0          0    AAA      Bumper-sticker letters
# 4          4    AAH          Circus exclamation
# 13        13    AAR            Interlaken river
# 19        19    AAS  Batteries for some remotes
# 20        20    AAU         Amateur sports org.
# ...      ...    ...                         ...
# 32443  32443    ZIT                 Bit of acne
# 32446  32446    ZOA         Animal group suffix
# 32448  32448    ZOE            Actress Caldwell
# 32456  32456    ZOO               Chaotic place
# 32468  32468    ZSA          Eva's half-sister?
#
#                                                clue_2  \
# 0      Grp. that offers International Driving Permits
# 4                                   Foot rub reaction
# 13                       River flowing into the Rhine
# 19                                    Furby batteries
# 20                               Jr. Olympics sponsor
# ...                                               ...
# 32443                                Clearasil target
# 32446                             Animal group suffix
# 32448                           Actress/model Kravitz
# 32456                   Dr. Seuss' "If I Ran the ___"
# 32468                              Eva's half-sister?
#
#                              clue_3                               clue_4  \
# 0       Minor-league classification                      Motorist's org.
# 4                       Ooh and ___                      Open wide sound
# 13             River in Switzerland                          Swiss river
# 19                 Remote batteries                      Small batteries
# 20             Junior Olympics org.  Org. that awards the Sullivan Award
# ...                             ...                                  ...
# 32443              Clearasil target                        Minor blemish
# 32446          Animals, in taxonomy                      Animals: Suffix
# 32448  Kravitz of "Big Little Lies"                     Muppet in a tutu
# 32456         Madhouse, so to speak                            Menagerie
# 32468        Hungarian half sister?                When doubled, a Gabor
#
#                                       clue_5  \
# 0                           Org. with towers
# 4      Reaction to a cold drink on a hot day
# 13                               Swiss river
# 19                           Small batteries
# 20      Org. that bestows the Sullivan Award
# ...                                      ...
# 32443                                 Pimple
# 32446                        Animals: Suffix
# 32448                       Playwright Akins
# 32456             Morning ___ (radio format)
# 32468                  When doubled, a Gabor
#
#                                                   clue_6  \
# 0                               Roadside assistance grp.
# 4                                    Sound of wonderment
# 13                                           Swiss river
# 19                                    Smallish batteries
# 20     Org. with the Sullivan Award for character, le...
# ...                                                  ...
# 32443                                    Proactiv target
# 32446                   Combining form meaning "animals"
# 32448                          Pulitzer playwright Akins
# 32456                                    Petting setting
# 32468                              When doubled, a Gabor
#
#                                                   clue_7  \
# 0                               Roadside assistance org.
# 4                                     That hit the spot!
# 13                                           Swiss river
# 19                       Smoke detector batteries, often
# 20     Org. with the Sullivan Award for character, le...
# ...                                                  ...
# 32443                                    Single outbreak
# 32446                                 Ending with proto-
# 32448                              Pulitzer winner Akins
# 32456                             Place to put stock in?
# 32468             When doubled, a Hungarian in Hollywood
#
#                                           clue_8  \
# 0                                  Small battery
# 4                                    That's nice
# 13                                   Swiss river
# 19                                Some batteries
# 20     Org. with the annual Junior Olympic Games
# ...                                          ...
# 32443                                 Teen's woe
# 32446                          Organisms: Suffix
# 32448                        Saldana of "Avatar"
# 32456           Place to see pandas and panthers
# 32468    When doubled, onetime name in Hollywood
#
#                                      clue_9                           clue_10  \
# 0                         Strong, as a bond                   Top bond rating
# 4                            What a relief!                  Word to a doctor
# 13               Swiss river into the Rhine          Swiss river to the Rhine
# 19                Some remote power sources                       ___ in Able
# 20             Sports For All, Forever org.  Sports org. for nonprofessionals
# ...                                     ...                               ...
# 32443                     Temple spot, say?      Unwanted blemish, informally
# 32446                    Suffix with proto-                   Taxonomy suffix
# 32448  Saldana of "Guardians of the Galaxy"           Saldana who plays Uhura
# 32456            Place with moving exhibits              San Diego attraction
# 32468  When repeated, name in old Hollywood  When repeated, one of the Gabors
#
#        clue_pct  length
# 0      0.893993       3
# 4      0.820230       3
# 13     0.522527       3
# 19     0.678004       3
# 20     0.166078       3
# ...         ...     ...
# 32443  0.442580       3
# 32446  0.071555       3
# 32448  0.477473       3
# 32456  0.641343       3
# 32468  0.178004       3
#
# [2264 rows x 14 columns]

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %%
character_set = list(alphabet)+[alphabet[i]+alphabet[j] for i in range(26) for j in range(i,26)]

# %%
len(character_set)
# Out:
# 377

# %%
character_set[-1]
# Out:
# 'ZZ'

# %%
char_table = {ch:n for n,ch in enumerate(character_set)}
idx_table = {n:ch for n,ch in enumerate(character_set)}

# %%
def decompose_word(w):
    if len(w) == 0:
        return []
    elif len(w) == 1:
        return [[w]]
    elif len(w) == 2:
        return [[w[0],w[1]],["".join(sorted(w))]]
    else:
        out = []
        first = w[0]
        first_suffix = decompose_word(w[1:])
        for i in first_suffix:
            out.append([first]+i)
        pair = "".join(sorted(w[:2]))
        second_suffix = decompose_word(w[2:])
        for i in second_suffix:
            out.append([pair]+i)
        return out

# %%
def decomp_to_idx(l):
    return tuple(char_table[i] for i in l)

# %%
decompose_word("ZYDECO")
# Out:
# [['Z', 'Y', 'D', 'E', 'C', 'O'],
#  ['Z', 'Y', 'D', 'E', 'CO'],
#  ['Z', 'Y', 'D', 'CE', 'O'],
#  ['Z', 'Y', 'DE', 'C', 'O'],
#  ['Z', 'Y', 'DE', 'CO'],
#  ['Z', 'DY', 'E', 'C', 'O'],
#  ['Z', 'DY', 'E', 'CO'],
#  ['Z', 'DY', 'CE', 'O'],
#  ['YZ', 'D', 'E', 'C', 'O'],
#  ['YZ', 'D', 'E', 'CO'],
#  ['YZ', 'D', 'CE', 'O'],
#  ['YZ', 'DE', 'C', 'O'],
#  ['YZ', 'DE', 'CO']]

# %%
[decomp_to_idx(x) for x in decompose_word("ZYDECO")]
# Out:
# [(25, 24, 3, 4, 2, 14),
#  (25, 24, 3, 4, 89),
#  (25, 24, 3, 79, 14),
#  (25, 24, 102, 2, 14),
#  (25, 24, 102, 89),
#  (25, 122, 4, 2, 14),
#  (25, 122, 4, 89),
#  (25, 122, 79, 14),
#  (375, 3, 4, 2, 14),
#  (375, 3, 4, 89),
#  (375, 3, 79, 14),
#  (375, 102, 2, 14),
#  (375, 102, 89)]

# %%
tags_to_word_index =[]
tags_by_length = defaultdict(list)
checked_tags = set()
for i, w, p in zip(clues["index"], clues["answer"], clues["clue_pct"]):
    d = decompose_word(w)
    for t in d:
        tags = decomp_to_idx(t)
        tags_to_word_index.append((i,tags))
        tags_by_length[len(tags)].append((tags,p))

# %%
len(tags_by_length)
# Out:
# 14

# %%
for l in tags_by_length.keys():
    with open(f"data/tags_length_{l}.json", "w") as f:
        json.dump(tags_by_length[l],f)

# %%
with open("data/tags_to_word_index.json","w") as f:
    json.dump(tags_to_word_index, f)
