# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import json

# %%
clues = pd.read_csv("clues_clean.csv").drop("Unnamed: 0", axis=1).reset_index()

# %%
clues.sample(10)
# Out:
#        index   answer                     clue_1  \
# 23035  23035  RECEDES                   Dwindles
# 29071  29071     TFAL       Big name in cookware
# 12541  12541  HIDALGO  2004 Viggo Mortensen film
# 32237  32237   YESMAN  Hardly the assertive type
# 12771  12771    HONES      Cutting edge creators
# 22436  22436     PURL           Knit alternative
# 1515    1515    AMUCK      Bad way to run (Var.)
# 6954    6954   DEARME                       Alas
# 11970  11970  HADATIT                    Battled
# 19190  19190      NSA  Code-breaking govt. group
#
#                                               clue_2  \
# 23035                                           Ebbs
# 29071                     Brand of nonstick cookware
# 12541                     2004 Viggo Mortensen movie
# 32237                         He's inclined to agree
# 12771                                     Fine-tunes
# 22436                             Knit one  ____ two
# 1515   Duck ___ (classic Warner Bros. cartoon short)
# 6954                                  Good gracious!
# 11970                                  Came to blows
# 19190                       Counterintelligence org.
#
#                                        clue_3  \
# 23035                                    Ebbs
# 29071  Cookware brand hidden in "crestfallen"
# 12541                          Gentleman: Sp.
# 32237                                  Stooge
# 12771                              Fine-tunes
# 22436                       Knit one, ___ two
# 1515    Duck ___ (classic Warner Bros. short)
# 6954                           Good gracious!
# 11970        Didn't shrink from the challenge
# 19190                      Cryptanalysis org.
#
#                                            clue_4  \
# 23035                                  Falls back
# 29071  Cookware brand that's an anagram of "flat"
# 12541                          Horse film of 2004
# 32237                                   Sycophant
# 12771                             Gets an edge on
# 22436                              Knit's partner
# 1515                                     Frenzied
# 6954                            Goodness gracious
# 11970                                      Fought
# 19190                  Grp. concerned with SIGINT
#
#                                          clue_5                     clue_6  \
# 23035                                 Goes back                 Moves away
# 29071  Kitchenware brand with a hyphenated name             Nonstick brand
# 12541                        Horse film of 2004          Spanish gentleman
# 32237                                 Sycophant                  Sycophant
# 12771                                  Perfects                   Perfects
# 22436                       Knitter's direction           Knitter's stitch
# 1515                             Frenzied: Var.                In a frenzy
# 6954                         Goodness gracious!          Heavens to Betsy!
# 11970                                    Fought           Joined the fight
# 19190                            Hush-hush org.  Part of the Defense Dept.
#
#                             clue_7                   clue_8  \
# 23035    Moves back, as a hairline                 Subsides
# 29071      Nonstick cookware brand  Nonstick cookware brand
# 12541             Spanish nobleman         Spanish nobleman
# 32237  The animated Smithers, e.g.                    Toady
# 12771                    Practices                 Sharpens
# 22436                Knitting term            Knitting term
# 1515   In a wild and crazy fashion           One way to run
# 6954                 I do declare!              Oh heavens!
# 11970              Joined the fray             Locked horns
# 19190            Surveillance org.             Tapping grp.
#
#                            clue_9                             clue_10  \
# 23035                   Withdraws                           Withdraws
# 29071     Nonstick cookware brand       Purveyor of nonstick cookware
# 12541  State north of Mexico City  The Father of Mexican Independence
# 32237                       Toady                  Unlikely dissenter
# 12771                    Sharpens                            Works on
# 22436           Reversal of sorts                          Small loop
# 1515               Out of control                  Sort of way to run
# 6954         Oh, what am I to do?                   Worrywart's words
# 11970                    Scrapped                    Started fighting
# 19190            Ultrasecret org.                    Ultrasecret org.
#
#        clue_pct
# 23035  0.625680
# 29071  0.185379
# 12541  0.494450
# 32237  0.792056
# 12771  0.734142
# 22436  0.372924
# 1515   0.218686
# 6954   0.918282
# 11970  0.059630
# 19190  0.867491

# %%
clues["length"]=[len(x) for x in clues.answer]

# %%
clues_by_length = {l:t for l,t in clues.groupby("length")}

# %%
clues_by_length[3]
# Out:
#        index answer                      clue_1  \
# 0          0    AAA      Bumper-sticker letters
# 4          4    AAH          Circus exclamation
# 13        13    AAR            Interlaken river
# 19        19    AAS  Batteries for some remotes
# 20        20    AAU         Amateur sports org.
# ...      ...    ...                         ...
# 32443  32443    ZIT                 Bit of acne
# 32446  32446    ZOA         Animal group suffix
# 32448  32448    ZOE            Actress Caldwell
# 32456  32456    ZOO               Chaotic place
# 32468  32468    ZSA          Eva's half-sister?
#
#                                                clue_2  \
# 0      Grp. that offers International Driving Permits
# 4                                   Foot rub reaction
# 13                       River flowing into the Rhine
# 19                                    Furby batteries
# 20                               Jr. Olympics sponsor
# ...                                               ...
# 32443                                Clearasil target
# 32446                             Animal group suffix
# 32448                           Actress/model Kravitz
# 32456                   Dr. Seuss' "If I Ran the ___"
# 32468                              Eva's half-sister?
#
#                              clue_3                               clue_4  \
# 0       Minor-league classification                      Motorist's org.
# 4                       Ooh and ___                      Open wide sound
# 13             River in Switzerland                          Swiss river
# 19                 Remote batteries                      Small batteries
# 20             Junior Olympics org.  Org. that awards the Sullivan Award
# ...                             ...                                  ...
# 32443              Clearasil target                        Minor blemish
# 32446          Animals, in taxonomy                      Animals: Suffix
# 32448  Kravitz of "Big Little Lies"                     Muppet in a tutu
# 32456         Madhouse, so to speak                            Menagerie
# 32468        Hungarian half sister?                When doubled, a Gabor
#
#                                       clue_5  \
# 0                           Org. with towers
# 4      Reaction to a cold drink on a hot day
# 13                               Swiss river
# 19                           Small batteries
# 20      Org. that bestows the Sullivan Award
# ...                                      ...
# 32443                                 Pimple
# 32446                        Animals: Suffix
# 32448                       Playwright Akins
# 32456             Morning ___ (radio format)
# 32468                  When doubled, a Gabor
#
#                                                   clue_6  \
# 0                               Roadside assistance grp.
# 4                                    Sound of wonderment
# 13                                           Swiss river
# 19                                    Smallish batteries
# 20     Org. with the Sullivan Award for character, le...
# ...                                                  ...
# 32443                                    Proactiv target
# 32446                   Combining form meaning "animals"
# 32448                          Pulitzer playwright Akins
# 32456                                    Petting setting
# 32468                              When doubled, a Gabor
#
#                                                   clue_7  \
# 0                               Roadside assistance org.
# 4                                     That hit the spot!
# 13                                           Swiss river
# 19                       Smoke detector batteries, often
# 20     Org. with the Sullivan Award for character, le...
# ...                                                  ...
# 32443                                    Single outbreak
# 32446                                 Ending with proto-
# 32448                              Pulitzer winner Akins
# 32456                             Place to put stock in?
# 32468             When doubled, a Hungarian in Hollywood
#
#                                           clue_8  \
# 0                                  Small battery
# 4                                    That's nice
# 13                                   Swiss river
# 19                                Some batteries
# 20     Org. with the annual Junior Olympic Games
# ...                                          ...
# 32443                                 Teen's woe
# 32446                          Organisms: Suffix
# 32448                        Saldana of "Avatar"
# 32456           Place to see pandas and panthers
# 32468    When doubled, onetime name in Hollywood
#
#                                      clue_9                           clue_10  \
# 0                         Strong, as a bond                   Top bond rating
# 4                            What a relief!                  Word to a doctor
# 13               Swiss river into the Rhine          Swiss river to the Rhine
# 19                Some remote power sources                       ___ in Able
# 20             Sports For All, Forever org.  Sports org. for nonprofessionals
# ...                                     ...                               ...
# 32443                     Temple spot, say?      Unwanted blemish, informally
# 32446                    Suffix with proto-                   Taxonomy suffix
# 32448  Saldana of "Guardians of the Galaxy"           Saldana who plays Uhura
# 32456            Place with moving exhibits              San Diego attraction
# 32468  When repeated, name in old Hollywood  When repeated, one of the Gabors
#
#        clue_pct  length
# 0      0.893993       3
# 4      0.820230       3
# 13     0.522527       3
# 19     0.678004       3
# 20     0.166078       3
# ...         ...     ...
# 32443  0.442580       3
# 32446  0.071555       3
# 32448  0.477473       3
# 32456  0.641343       3
# 32468  0.178004       3
#
# [2264 rows x 14 columns]

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %%
character_set = list(alphabet)+[alphabet[i]+alphabet[j] for i in range(26) for j in range(i,26)]

# %%
len(character_set)
# Out:
# 377

# %%
character_set[-1]
# Out:
# 'ZZ'

# %%
char_table = {ch:n for n,ch in enumerate(character_set)}
idx_table = {n:ch for n,ch in enumerate(character_set)}

# %%
def decompose_word(w):
    if len(w) == 0:
        return []
    elif len(w) == 1:
        return [[w]]
    elif len(w) == 2:
        return [[w[0],w[1]],["".join(sorted(w))]]
    else:
        out = []
        first = w[0]
        first_suffix = decompose_word(w[1:])
        for i in first_suffix:
            out.append([first]+i)
        pair = "".join(sorted(w[:2]))
        second_suffix = decompose_word(w[2:])
        for i in second_suffix:
            out.append([pair]+i)
        return out

# %%
def decomp_to_idx(l):
    return tuple(char_table[i] for i in l)

# %%
decompose_word("ZYDECO")
# Out:
# [['Z', 'Y', 'D', 'E', 'C', 'O'],
#  ['Z', 'Y', 'D', 'E', 'CO'],
#  ['Z', 'Y', 'D', 'CE', 'O'],
#  ['Z', 'Y', 'DE', 'C', 'O'],
#  ['Z', 'Y', 'DE', 'CO'],
#  ['Z', 'DY', 'E', 'C', 'O'],
#  ['Z', 'DY', 'E', 'CO'],
#  ['Z', 'DY', 'CE', 'O'],
#  ['YZ', 'D', 'E', 'C', 'O'],
#  ['YZ', 'D', 'E', 'CO'],
#  ['YZ', 'D', 'CE', 'O'],
#  ['YZ', 'DE', 'C', 'O'],
#  ['YZ', 'DE', 'CO']]

# %%
[decomp_to_idx(x) for x in decompose_word("ZYDECO")]
# Out:
# [(25, 24, 3, 4, 2, 14),
#  (25, 24, 3, 4, 89),
#  (25, 24, 3, 79, 14),
#  (25, 24, 102, 2, 14),
#  (25, 24, 102, 89),
#  (25, 122, 4, 2, 14),
#  (25, 122, 4, 89),
#  (25, 122, 79, 14),
#  (375, 3, 4, 2, 14),
#  (375, 3, 4, 89),
#  (375, 3, 79, 14),
#  (375, 102, 2, 14),
#  (375, 102, 89)]

# %%
tags_to_word_index =[]
tags_by_length = defaultdict(list)
checked_tags = set()
for i, w, p in zip(clues["index"], clues["answer"], clues["clue_pct"]):
    d = decompose_word(w)
    for t in d:
        tags = decomp_to_idx(t)
        tags_to_word_index.append((i,tags))
        tags_by_length[len(tags)].append((tags,p))

# %%
len(tags_by_length)
# Out:
# 14

# %%
with open("tags_by_length.json", "w") as f:
    json.dump(tags_by_length,f, indent = 3)

# %%
with open("tags_to_word_index.json","w") as f:
    json.dump(tags_to_word_index, f, indent=3)
